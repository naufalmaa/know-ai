# %%
import weaviate

client = weaviate.connect_to_local(
    host="127.0.0.1",  # Use a string to specify the host
    port=8080,
    grpc_port=50051,
)

print(client.is_ready())
# Out:
# ---------------------------------------------------------------------------
# UnexpectedStatusCodeError                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import weaviate
# ----> 3 client = weaviate.connect_to_local(
#       4     host="127.0.0.1",  # Use a string to specify the host
#       5     port=8080,
#       6     grpc_port=50051,
#       7 )
#       9 print(client.is_ready())
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\helpers.py:193, in connect_to_local(host, port, grpc_port, headers, additional_config, skip_init_checks, auth_credentials)
#     142 def connect_to_local(
#     143     host: str = "localhost",
#     144     port: int = 8080,
#    (...)    149     auth_credentials: Union[str, AuthCredentials, None] = None,
#     150 ) -> WeaviateClient:
#     151     """Connect to a local Weaviate instance deployed using Docker compose with standard port configurations.
#     152
#     153     This method handles automatically connecting to Weaviate but not automatically closing the connection. Once you are done with the client
#    (...)    191         >>> # The connection is automatically closed when the context is exited.
#     192     """
# --> 193     return __connect(
#     194         WeaviateClient(
#     195             connection_params=ConnectionParams(
#     196                 http=ProtocolParams(host=host, port=port, secure=False),
#     197                 grpc=ProtocolParams(host=host, port=grpc_port, secure=False),
#     198             ),
#     199             additional_headers=headers,
#     200             additional_config=additional_config,
#     201             skip_init_checks=skip_init_checks,
#     202             auth_client_secret=__parse_auth_credentials(auth_credentials),
#     203         )
#     204     )
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\helpers.py:371, in __connect(client)
#     369 except Exception as e:
#     370     client.close()
# --> 371     raise e
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\helpers.py:367, in __connect(client)
#     365 def __connect(client: WeaviateClient) -> WeaviateClient:
#     366     try:
# --> 367         client.connect()
#     368         return client
#     369     except Exception as e:
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\client_executor.py:149, in _WeaviateClientExecutor.connect(self)
#     137 def connect(self) -> executor.Result[None]:
#     138     """Connect to the Weaviate instance performing all the necessary checks.
#     139
#     140     If you have specified `skip_init_checks` in the constructor then this method will not perform any runtime checks
#    (...)    147         weaviate.exceptions.UnexpectedStatusCodeError: If weaviate reports a none OK status.
#     148     """
# --> 149     return executor.execute(
#     150         response_callback=lambda _: None,
#     151         method=self._connection.connect,
#     152     )
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\executor.py:99, in execute(method, response_callback, exception_callback, *args, **kwargs)
#      97     return resp_call
#      98 except Exception as e:
# ---> 99     return cast(T, exception_callback(e))
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\executor.py:38, in raise_exception(e)
#      37 def raise_exception(e: Exception) -> Any:
# ---> 38     raise e
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\executor.py:80, in execute(method, response_callback, exception_callback, *args, **kwargs)
#      71 def execute(
#      72     method: SyncOrAsyncMethod[P, R],
#      73     response_callback: SyncOrAsyncCallback[R, T, A],
#    (...)     77 ) -> Union[T, Awaitable[T], Awaitable[A]]:
#      78     # wrap method call in try-except to catch exceptions for sync method
#      79     try:
# ---> 80         call = method(*args, **kwargs)
#      81         if isinstance(call, Awaitable):
#      83             async def _execute() -> T:
#      84                 # wrap await in try-except to catch exceptions for async method
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\v4.py:922, in ConnectionSync.connect(self)
#     920 # need this to get the version of weaviate for version checks and proper GRPC configuration
#     921 try:
# --> 922     meta = executor.result(self.get_meta(False))
#     923     self._weaviate_version = _ServerVersion.from_string(meta["version"])
#     924     if "grpcMaxMessageSize" in meta:
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\v4.py:889, in _ConnectionBase.get_meta(self, check_is_connected)
#     886     assert data is not None
#     887     return data
# --> 889 return executor.execute(
#     890     response_callback=resp,
#     891     method=self.get,
#     892     path="/meta",
#     893     check_is_connected=check_is_connected,
#     894 )
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\executor.py:99, in execute(method, response_callback, exception_callback, *args, **kwargs)
#      97     return resp_call
#      98 except Exception as e:
# ---> 99     return cast(T, exception_callback(e))
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\executor.py:38, in raise_exception(e)
#      37 def raise_exception(e: Exception) -> Any:
# ---> 38     raise e
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\executor.py:95, in execute(method, response_callback, exception_callback, *args, **kwargs)
#      92             return cast(T, exception_callback(e))
#      94     return _execute()
# ---> 95 resp_call = response_callback(call)
#      96 assert not isinstance(resp_call, Awaitable)
#      97 return resp_call
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\connect\v4.py:885, in _ConnectionBase.get_meta.<locals>.resp(res)
#     884 def resp(res: Response) -> Dict[str, str]:
# --> 885     data = _decode_json_response_dict(res, "Meta endpoint")
#     886     assert data is not None
#     887     return data
#
# File d:\Naufal\Working Folder\Project\SKK Migas_Prospektivitas\app-new\know-ai\.venv\Lib\site-packages\weaviate\util.py:694, in _decode_json_response_dict(response, location)
#     691     except (httpx.DecodingError, json.decoder.JSONDecodeError):
#     692         raise ResponseCannotBeDecodedError(location, response)
# --> 694 raise UnexpectedStatusCodeError(location, response)
#
# UnexpectedStatusCodeError: Meta endpoint! Unexpected status code: 404, with response body: None.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
